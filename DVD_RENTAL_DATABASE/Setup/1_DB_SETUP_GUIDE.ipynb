# %% [markdown]
# <div style="
#     font-family: 'Roboto', sans-serif;
#     color: white;
#     background-color: #AF0404;
#     padding: 1%;
#     border-radius: 10px;
#     font-size: 2em;
#     text-align: center;
# ">
# DVD RENTAL DB SETUP
# </div>

# %% [markdown]
# <div style="
#     color: black;
#     background-color: #f0f0f0ff;
#     border-radius: 10px;
#     padding: 1%;
#     font-size: 1em;
#     border: 1px solid #3f37c9;
# ">
#     📍 <b>NOTE</b>: This notebook is intended to:
#     <ul>
#         <li>Provide comprehensive guide to setup dvdrental database.</li>
#     </ul>
# </div>

# %% [markdown]
# <div style="
#     color: black;
#     background-color: #f0f0f0ff;
#     border-radius: 10px;
#     padding: 1%;
#     font-size: 1em;
#     border: 1px solid #3f37c9;
# ">
# <p><strong>Option 1: Load the sample database using the psql</strong></p>
#
# <p>To create a database and load data from an archive file, follow these steps:</p>
#
# <ol>
#   <li>Connect to the PostgreSQL database server using <code>psql</code> or pgAdmin.</li>
#   <li>Create a blank database called <code>dvdrental</code>.</li>
#   <li>Load data from the sample database file into the <code>dvdrental</code> database using <code>pg_restore</code>.</li>
# </ol>
#
# <h3>1) Create the dvdrental database</h3>
# <p>Open Command Prompt (Windows) or Terminal (Linux/Mac) and connect:</p>
# <pre><code>psql -U postgres
# </code></pre>
#
# <p>Enter the password for the <code>postgres</code> user. After successful login, the prompt looks like:</p>
# <pre><code>postgres=#
# </code></pre>
#
# <p>Create the <code>dvdrental</code> database:</p>
# <pre><code>CREATE DATABASE dvdrental;
# </code></pre>
#
# <p>Output:</p>
# <pre><code>CREATE DATABASE
# </code></pre>
#
# <h3>2) Download and load the sample database</h3>
# <p>Download <code>dvdrental.zip</code> and extract <code>dvdrental.tar</code> to a directory, for example:</p>
# <pre><code>D:\sampledb\postgres\dvdrental.tar
# </code></pre>
#
# <p>Load the database using <code>pg_restore</code> in the command line:</p>
# <pre><code>pg_restore -U postgres -d dvdrental D:\sampledb\postgres\dvdrental.tar
# </code></pre>
#
# <p><strong>Explanation:</strong></p>
# <ul>
#   <li><code>-U postgres</code> → Connect as postgres user</li>
#   <li><code>-d dvdrental</code> → Target database name</li>
# </ul>
#
# <p>Enter the postgres password when prompted. Data will be loaded into <code>dvdrental</code>.</p>
#
# <h3>3) Verify the sample database</h3>
# <p>Connect to PostgreSQL server and switch to the dvdrental database:</p>
# <pre><code>psql -U postgres
# \c dvdrental
# </code></pre>
#
# <p>The prompt changes to:</p>
# <pre><code>dvdrental=#
# </code></pre>
#
# <p>List all tables:</p>
# <pre><code>\dt
# </code></pre>
#
# <p>Sample Output:</p>
# <pre><code> Schema |     Name      | Type  |  Owner
# --------+---------------+-------+----------
#  public | actor         | table | postgres
#  public | address       | table | postgres
#  public | category      | table | postgres
#  public | city          | table | postgres
#  public | country       | table | postgres
#  public | customer      | table | postgres
#  public | film          | table | postgres
#  public | film_actor    | table | postgres
#  public | film_category | table | postgres
#  public | inventory     | table | postgres
#  public | language      | table | postgres
#  public | payment       | table | postgres
#  public | rental        | table | postgres
#  public | staff         | table | postgres
#  public | store         | table | postgres
# (15 rows)
# </code></pre>
#
# </div>

# %% [markdown]
# <div style="
#     color: black;
#     background-color: #d9d9d9;
#     border-radius: 10px;
#     padding: 1%;
#     font-size: 1em;
#     border: 1px solid #3f37c9;
# ">
#     <p><strong>Option 2: Restore in pgAdmin GUI (No Command Needed)</strong></p>
#
# <ol> <li><strong>Open pgAdmin</strong><br> Launch from Start Menu → pgAdmin 4 </li> <li><strong>Connect to Server</strong><br> Enter your master password </li> <li><strong>Navigate to the Database Section</strong><br> Expand: Servers &gt; PostgreSQL </li> <li><strong>Right-click on "Databases"</strong><br> Click <em>Create</em> → <em>Database...</em> </li> <li><strong>Fill in the Form:</strong> <ul> <li><strong>Database name:</strong>  <em>dvdrental</em></li> <li><strong>Owner:</strong> Leave as <em>postgres</em> or choose another user</li> <li>Leave other settings default unless you need advanced configuration</li> </ul> </li> <li><strong>Click Save</strong></li> </ol> <p>Your new database will now appear in the left panel under <strong>Databases</strong>.</p>
# <p><strong>NOW:</strong></p>
# <ol>
#   <li>Open pgAdmin</li>
#   <li>Right-click on the database → <strong>Restore</strong></li>
#   <li>Select <strong>Format = Custom or Tar</strong></li>
#   <li>Browse to your <code>.tar</code> file</li>
#   <li>Click <strong>Restore</strong></li>
# </ol>
#
# </div>
